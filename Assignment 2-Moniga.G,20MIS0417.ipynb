# %% [markdown]
# ### NAME:MONIGA.G
# ### REG NO:20MIS0417
# ### CAMPUS:VELLORE

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("This project belongs to Moniga.G bearing Reg.No as 20MIS0417 from VIT VELLORE")
# Out:
# This project belongs to Moniga.G bearing Reg.No as 20MIS0417 from VIT VELLORE

# %% [markdown]
# ## 1. Downloading the dataset is done in the respective folder so no need to download once again
#
# ## 2. performing :Loading the dataset

# %%
data=pd.read_csv('titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## 3.1 Univariate analysis
# #### a. histogram

# %%
#histogram for age
data['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
plt.hist(data['age'])
plt.xlabel('age')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# #### b.countplot

# %%
# count plot for age 
data['age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %%
#count plot for the column survived
data['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %% [markdown]
# #### c. box plot

# %%
#box plot for the column fare 
plt.boxplot(data['fare'])
plt.xlabel('avg range with outliers')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %% [markdown]
# #### d.pie chart

# %%
#pie chart for the decks
pi=data['deck'].value_counts()

# %%
pi
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
plt.pie(pi,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f08a1259c0>,
# ...
#  [Text(0.6724477763718097, 0.8705251220111966, ''),
#   Text(-0.9152072061978529, 0.6102423860430549, ''),
#   Text(-0.8757024206330114, -0.6656915731008503, ''),
#   Text(0.09351565763687049, -1.0960177105214786, ''),
#   Text(0.7985949812798709, -0.7564694679064071, ''),
#   Text(1.0424184599522142, -0.35123176728601024, ''),
#   Text(1.097893057002703, -0.06805024162528528, '')],
#  [Text(0.36678969620280527, 0.4748318847333799, '29.06'),
#   Text(-0.49920393065337426, 0.33285948329621173, '23.15'),
#   Text(-0.47765586579982433, -0.36310449441864556, '16.26'),
#   Text(0.051008540529202076, -0.5978278421026246, '15.76'),
#   Text(0.4355972625162932, -0.4126197097671311, '7.39'),
#   Text(0.5685918872466622, -0.1915809639741874, '6.40'),
#   Text(0.5988507583651107, -0.03711831361379196, '1.97')])

# %%
em=data['embark_town'].value_counts()
em
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
plt.pie(em,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f08ce33a60>,
# ...
#  [Text(-0.7128398214280038, 0.8377704870586524, ''),
#   Text(0.4614522559226597, -0.9985298270476893, ''),
#   Text(1.0595276168013974, -0.29563698894954155, '')],
#  [Text(-0.38882172077891114, 0.4569657202138104, '72.44'),
#   Text(0.25170123050326887, -0.5446526329351032, '18.90'),
#   Text(0.577924154618944, -0.16125653942702264, '8.66')])

# %% [markdown]
# ## 3.2 Bi-variate analysis
# ####  a.scatter plot

# %%
#scatter plot for fare amount of different ages
plt.scatter(data['fare'],data['age'])
plt.xlabel('Fare')
plt.ylabel('Age')
plt.show()
plt.scatter(data['fare'],data['survived'])
plt.xlabel('Fare')
plt.ylabel('survived')
plt.show()

# %% [markdown]
# #### b.bar plot

# %%
#bar plot
plt.bar(data['age'],data['fare'])
plt.xlabel ('Age')
plt.ylabel ('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
sns.barplot(data, x='sex', y='age')
plt.xlabel('Sex')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# #### c .joint plot

# %%
sns.jointplot(x='survived', y='pclass', data=data)

# %% [markdown]
# #### d.box plot

# %%
sns.boxplot(data, x='pclass', y='fare', hue='survived')
plt.xlabel('age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# ## 3.3 Multi-variate analysis
# #### a. pair plot

# %%
#### pair plot for multiple variate analysis
sns.pairplot(data)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
#for numerical variables
sns.pairplot(data, vars=['age', 'fare', 'sibsp', 'parch'], hue='survived')
plt.title('Pairwise scatter plot of multiple numerical variables')
plt.show()

# %% [markdown]
# #### b.heat map

# %%
data.corr()
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\1185648202.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %%
hm=data.corr()
sns.heatmap(hm)
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\3974116545.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm=data.corr()
# <Axes: >

# %%
corr_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()#for numerical values alone
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Perform descriptive statistics on the dataset

# %%
data.describe()#descriptive analysis
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Measure of Cetral Tendency- Mean, median and Mode

# %%
#a.Mean
data.mean()
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\1765974477.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
#b.Median
data.median()
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
#c.Mode
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %% [markdown]
# #### ranges

# %%
#range
a = data.select_dtypes(include=[int, float]).columns
a1=data[numeric_columns].max()
a1
# Out:
# survived      1.0000
# pclass        3.0000
# age          80.0000
# sibsp         8.0000
# parch         6.0000
# fare        512.3292
# dtype: float64

# %%
b = data.select_dtypes(include=[int, float]).columns
b1=data[numeric_columns].min()
b1
# Out:
# survived    0.00
# pclass      1.00
# age         0.42
# sibsp       0.00
# parch       0.00
# fare        0.00
# dtype: float64

# %%
range1=a1-b1
range1
# Out:
# survived      1.0000
# pclass        2.0000
# age          79.5800
# sibsp         8.0000
# parch         6.0000
# fare        512.3292
# dtype: float64

# %% [markdown]
# #### variance

# %%
#variance
data.var(numeric_only=True)#just for numerical values
# Out:
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64

# %% [markdown]
# #### standard deviation

# %%
#standard deviation
data.std(numeric_only=True)#just for numerical values
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %% [markdown]
# #### skewness

# %%
data.skew(numeric_only=True)
# Out:
# survived      0.478523
# pclass       -0.630548
# age           0.389108
# sibsp         3.695352
# parch         2.749117
# fare          4.787317
# adult_male   -0.420431
# alone        -0.420431
# dtype: float64

# %% [markdown]
# #### Kurtosis

# %%
data.kurt(numeric_only=True)
# Out:
# survived      -1.775005
# pclass        -1.280015
# age            0.178274
# sibsp         17.880420
# parch          9.778125
# fare          33.398141
# adult_male    -1.827345
# alone         -1.827345
# dtype: float64

# %% [markdown]
# #### QUANTILE RANGES

# %%
# inter quantile ranges
# IQr=Q3-Q1

# %%
quan= data.select_dtypes(include=[int, float]).columns
quantile=data[quan].quantile(q=[0.75,0.25])
quantile
# Out:
#       survived  pclass     age  sibsp  parch     fare
# 0.75       1.0     3.0  38.000    1.0    0.0  31.0000
# 0.25       0.0     2.0  20.125    0.0    0.0   7.9104

# %%
quantile.iloc[0]
# Out:
# survived     1.0
# pclass       3.0
# age         38.0
# sibsp        1.0
# parch        0.0
# fare        31.0
# Name: 0.75, dtype: float64

# %%
quantile.iloc[1]
# Out:
# survived     0.0000
# pclass       2.0000
# age         20.1250
# sibsp        0.0000
# parch        0.0000
# fare         7.9104
# Name: 0.25, dtype: float64

# %%
IQR=quantile.iloc[0]-quantile.iloc[1]
IQR#inter quantile range
# Out:
# survived     1.0000
# pclass       1.0000
# age         17.8750
# sibsp        1.0000
# parch        0.0000
# fare        23.0896
# dtype: float64

# %%
#upper extreme=Q3 +1.5 * IQR

upper_extreme=quantile.iloc[0]+(1.5*IQR)
upper_extreme
# Out:
# survived     2.5000
# pclass       4.5000
# age         64.8125
# sibsp        2.5000
# parch        0.0000
# fare        65.6344
# dtype: float64

# %%
#lower extreme=Q1 -1.5 * IQR
lower_extreme=quantile.iloc[1]-(1.5* IQR)
lower_extreme
# Out:
# survived    -1.5000
# pclass       0.5000
# age         -6.6875
# sibsp       -1.5000
# parch        0.0000
# fare       -26.7240
# dtype: float64

# %%
sns.boxplot(data.age)# box plot for the age column where the upper extreme is 64 and the lower is 0~6 months
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Handle the Missing values.

# %%
#if we have null value in the numerical column then we have to replace them with Mean or Median
# else if the column that has the null value is categorical based then it should be replaced with Mode
data.mean()
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\2214533302.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\MONIGA\AppData\Local\Temp\ipykernel_18960\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
#let us check for null values in the data set
data.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#it seems like we have null value for age so we have to replace them with the mean/median as they are numerical value
data['age'].fillna(data['age'].mean(),inplace=True)

# %%
data.isnull().sum()# now we have filled the null value of the age
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#similarly the deck,embark_town and embarked has some null value and these are categorical column
#embarked
mode_value = data['embarked'].mode()[0]
data['embarked'].fillna(mode_value,inplace=True)#have to use mode

# %%
data.isnull().sum()# now we have filled the null value of the embarked
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           687
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#deck
mode_value = data['deck'].mode()[0]
data['deck'].fillna(mode_value,inplace=True)#have to use mode
data.isnull().sum()# now we have filled the null value of the deck
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
#embark_town
mode_value = data['embark_town'].mode()[0]
data['embark_town'].fillna(mode_value,inplace=True)#have to use mode
data.isnull().sum()# now we have filled the null value of the embark_town 0 indicates the absence of the null value
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# #### missing values are handled

# %% [markdown]
# ## 6. Find the outliers and replace the outliers

# %%
sns.boxplot(data.fare)# finding the outliers in the fare column
# Out:
# <Axes: >

# %%
ro=data.fare.quantile(0.90)
ro
# Out:
# 68.49000000000012

# %%
data1=data[data.fare<=ro]
sns.boxplot(data1.fare)
# Out:
# <Axes: >

# %% [markdown]
# ### Outliers are changed

# %% [markdown]
# ## 7. Check for Categorical columns and perform encoding.

# %% [markdown]
# #### Generally categorical column involves the column that are not numerical and involve some categorical division instead of the numerical values and numerical manipulation

# %%
data.info()#has the data type as value so it is easier to find which are not numerical and add them as the numerical data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     674 non-null    int64
#  1   pclass       674 non-null    int64
#  2   sex          674 non-null    object
#  3   age          674 non-null    float64
#  4   sibsp        674 non-null    int64
#  5   parch        674 non-null    int64
#  6   fare         674 non-null    float64
#  7   embarked     674 non-null    object
#  8   class        674 non-null    object
#  9   who          674 non-null    object
#  10  adult_male   674 non-null    bool
#  11  deck         674 non-null    object
#  12  embark_town  674 non-null    object
#  13  alive        674 non-null    object
#  14  alone        674 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 91.2+ KB

# %% [markdown]
# #### From the above info we came to know that the following columns are categorical column
# #### 1.sex, 2.embarked, 3.class,4.who ,5.adult_male,6.deck,7.embark_town,8.alive,9.alone
# #### we have to apply encoding in these columns either using the label encoding or one hot encoding
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()#Label Encoder-they generally assign the numerical value for each category

# %%
#sex
data.sex=le.fit_transform(data.sex)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500        S  Third
# 2         1       3    0  26.000000      0      0   7.9250        S  Third
# 3         1       1    0  35.000000      1      0  53.1000        S  First
# 4         0       3    1  35.000000      0      0   8.0500        S  Third
# 5         0       3    1  29.699118      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True
# 5    man        True    C   Queenstown    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00        S  Second
# 887         1       1    0  19.000000      0      0  30.00        S   First
# 888         0       3    0  29.699118      1      2  23.45        S   Third
# 889         1       1    1  26.000000      0      0  30.00        C   First
# 890         0       3    1  32.000000      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True    C  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    C  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    C   Queenstown    no   True

# %%
#embarked
data.embarked =le.fit_transform(data.embarked)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500         2  Third
# 2         1       3    0  26.000000      0      0   7.9250         2  Third
# 3         1       1    0  35.000000      1      0  53.1000         2  First
# 4         0       3    1  35.000000      0      0   8.0500         2  Third
# 5         0       3    1  29.699118      0      0   8.4583         1  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True
# 5    man        True    C   Queenstown    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00         2  Second
# 887         1       1    0  19.000000      0      0  30.00         2   First
# 888         0       3    0  29.699118      1      2  23.45         2   Third
# 889         1       1    1  26.000000      0      0  30.00         0   First
# 890         0       3    1  32.000000      0      0   7.75         1   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True    C  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    C  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    C   Queenstown    no   True

# %%
#who
data.who =le.fit_transform(data.who)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500         2  Third
# 2         1       3    0  26.000000      0      0   7.9250         2  Third
# 3         1       1    0  35.000000      1      0  53.1000         2  First
# 4         0       3    1  35.000000      0      0   8.0500         2  Third
# 5         0       3    1  29.699118      0      0   8.4583         1  Third
#
#    who  adult_male deck  embark_town alive  alone
# 0    1        True    C  Southampton    no  False
# 2    2       False    C  Southampton   yes   True
# 3    2       False    C  Southampton   yes  False
# 4    1        True    C  Southampton    no   True
# 5    1        True    C   Queenstown    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00         2  Second
# 887         1       1    0  19.000000      0      0  30.00         2   First
# 888         0       3    0  29.699118      1      2  23.45         2   Third
# 889         1       1    1  26.000000      0      0  30.00         0   First
# 890         0       3    1  32.000000      0      0   7.75         1   Third
#
#      who  adult_male deck  embark_town alive  alone
# 886    1        True    C  Southampton    no   True
# 887    2       False    B  Southampton   yes   True
# 888    2       False    C  Southampton    no  False
# 889    1        True    C    Cherbourg   yes   True
# 890    1        True    C   Queenstown    no   True

# %%
#deck
data.deck =le.fit_transform(data.deck)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500         2  Third
# 2         1       3    0  26.000000      0      0   7.9250         2  Third
# 3         1       1    0  35.000000      1      0  53.1000         2  First
# 4         0       3    1  35.000000      0      0   8.0500         2  Third
# 5         0       3    1  29.699118      0      0   8.4583         1  Third
#
#    who  adult_male  deck  embark_town alive  alone
# 0    1        True     2  Southampton    no  False
# 2    2       False     2  Southampton   yes   True
# 3    2       False     2  Southampton   yes  False
# 4    1        True     2  Southampton    no   True
# 5    1        True     2   Queenstown    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00         2  Second
# 887         1       1    0  19.000000      0      0  30.00         2   First
# 888         0       3    0  29.699118      1      2  23.45         2   Third
# 889         1       1    1  26.000000      0      0  30.00         0   First
# 890         0       3    1  32.000000      0      0   7.75         1   Third
#
#      who  adult_male  deck  embark_town alive  alone
# 886    1        True     2  Southampton    no   True
# 887    2       False     1  Southampton   yes   True
# 888    2       False     2  Southampton    no  False
# 889    1        True     2    Cherbourg   yes   True
# 890    1        True     2   Queenstown    no   True

# %%
#embark_town
data.embark_town =le.fit_transform(data.embark_town)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500         2  Third
# 2         1       3    0  26.000000      0      0   7.9250         2  Third
# 3         1       1    0  35.000000      1      0  53.1000         2  First
# 4         0       3    1  35.000000      0      0   8.0500         2  Third
# 5         0       3    1  29.699118      0      0   8.4583         1  Third
#
#    who  adult_male  deck  embark_town alive  alone
# 0    1        True     2            2    no  False
# 2    2       False     2            2   yes   True
# 3    2       False     2            2   yes  False
# 4    1        True     2            2    no   True
# 5    1        True     2            1    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00         2  Second
# 887         1       1    0  19.000000      0      0  30.00         2   First
# 888         0       3    0  29.699118      1      2  23.45         2   Third
# 889         1       1    1  26.000000      0      0  30.00         0   First
# 890         0       3    1  32.000000      0      0   7.75         1   Third
#
#      who  adult_male  deck  embark_town alive  alone
# 886    1        True     2            2    no   True
# 887    2       False     1            2   yes   True
# 888    2       False     2            2    no  False
# 889    1        True     2            0   yes   True
# 890    1        True     2            1    no   True

# %%
# alive
data.alive =le.fit_transform(data.alive)
data.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0         0       3    1  22.000000      1      0   7.2500         2  Third
# 2         1       3    0  26.000000      0      0   7.9250         2  Third
# 3         1       1    0  35.000000      1      0  53.1000         2  First
# 4         0       3    1  35.000000      0      0   8.0500         2  Third
# 5         0       3    1  29.699118      0      0   8.4583         1  Third
#
#    who  adult_male  deck  embark_town  alive  alone
# 0    1        True     2            2      0  False
# 2    2       False     2            2      1   True
# 3    2       False     2            2      1  False
# 4    1        True     2            2      0   True
# 5    1        True     2            1      0   True

# %%
data.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked   class  \
# 886         0       2    1  27.000000      0      0  13.00         2  Second
# 887         1       1    0  19.000000      0      0  30.00         2   First
# 888         0       3    0  29.699118      1      2  23.45         2   Third
# 889         1       1    1  26.000000      0      0  30.00         0   First
# 890         0       3    1  32.000000      0      0   7.75         1   Third
#
#      who  adult_male  deck  embark_town  alive  alone
# 886    1        True     2            2      0   True
# 887    2       False     1            2      1   True
# 888    2       False     2            2      0  False
# 889    1        True     2            0      1   True
# 890    1        True     2            1      0   True

# %% [markdown]
# ## One Hot Encoding

# %%
#class
data2=pd.get_dummies(data,columns=['class'])#splits them to the number of classes
data2.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  who  \
# 0         0       3    1  22.000000      1      0   7.2500         2    1
# 2         1       3    0  26.000000      0      0   7.9250         2    2
# 3         1       1    0  35.000000      1      0  53.1000         2    2
# 4         0       3    1  35.000000      0      0   8.0500         2    1
# 5         0       3    1  29.699118      0      0   8.4583         1    1
#
#    adult_male  deck  embark_town  alive  alone  class_First  class_Second  \
# 0        True     2            2      0  False            0             0
# 2       False     2            2      1   True            0             0
# 3       False     2            2      1  False            1             0
# 4        True     2            2      0   True            0             0
# 5        True     2            1      0   True            0             0
#
#    class_Third
# 0            1
# 2            1
# 3            0
# ...

# %%
data2.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked  who  \
# 886         0       2    1  27.000000      0      0  13.00         2    1
# 887         1       1    0  19.000000      0      0  30.00         2    2
# 888         0       3    0  29.699118      1      2  23.45         2    2
# 889         1       1    1  26.000000      0      0  30.00         0    1
# 890         0       3    1  32.000000      0      0   7.75         1    1
#
#      adult_male  deck  embark_town  alive  alone  class_First  class_Second  \
# 886        True     2            2      0   True            0             1
# 887       False     1            2      1   True            1             0
# 888       False     2            2      0  False            0             0
# 889        True     2            0      1   True            1             0
# 890        True     2            1      0   True            0             0
#
#      class_Third
# 886            0
# 887            0
# ...

# %%
#alone,alive,adult_male,class
data2=pd.get_dummies(data,columns=['alone','adult_male','class'])#splits them to the number of classes
data2.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  who  \
# 0         0       3    1  22.000000      1      0   7.2500         2    1
# 2         1       3    0  26.000000      0      0   7.9250         2    2
# 3         1       1    0  35.000000      1      0  53.1000         2    2
# 4         0       3    1  35.000000      0      0   8.0500         2    1
# 5         0       3    1  29.699118      0      0   8.4583         1    1
#
#    deck  embark_town  alive  alone_False  alone_True  adult_male_False  \
# 0     2            2      0            1           0                 0
# 2     2            2      1            0           1                 1
# 3     2            2      1            1           0                 1
# 4     2            2      0            0           1                 0
# 5     2            1      0            0           1                 0
#
#    adult_male_True  class_First  class_Second  class_Third
# ...

# %%
data2.tail()
# Out:
#      survived  pclass  sex        age  sibsp  parch   fare  embarked  who  \
# 886         0       2    1  27.000000      0      0  13.00         2    1
# 887         1       1    0  19.000000      0      0  30.00         2    2
# 888         0       3    0  29.699118      1      2  23.45         2    2
# 889         1       1    1  26.000000      0      0  30.00         0    1
# 890         0       3    1  32.000000      0      0   7.75         1    1
#
#      deck  embark_town  alive  alone_False  alone_True  adult_male_False  \
# 886     2            2      0            0           1                 0
# 887     1            2      1            0           1                 1
# 888     2            2      0            1           0                 1
# 889     2            0      1            0           1                 0
# 890     2            1      0            0           1                 0
#
#      adult_male_True  class_First  class_Second  class_Third
# ...

# %% [markdown]
# #### or one can perform label encoding in the following method too

# %%
from sklearn.preprocessing import LabelEncoder
categorical_columns = data.select_dtypes(include=['object']).columns


for column in categorical_columns:
  
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
print(data)
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 0           0       3    1  22.000000      1      0   7.2500         2      2
# 2           1       3    0  26.000000      0      0   7.9250         2      2
# 3           1       1    0  35.000000      1      0  53.1000         2      0
# 4           0       3    1  35.000000      0      0   8.0500         2      2
# 5           0       3    1  29.699118      0      0   8.4583         1      2
# ..        ...     ...  ...        ...    ...    ...      ...       ...    ...
# 886         0       2    1  27.000000      0      0  13.0000         2      1
# 887         1       1    0  19.000000      0      0  30.0000         2      0
# 888         0       3    0  29.699118      1      2  23.4500         2      2
# 889         1       1    1  26.000000      0      0  30.0000         0      0
# 890         0       3    1  32.000000      0      0   7.7500         1      2
#
# ...

# %% [markdown]
# ## 8. Split the data into dependent and independent variables

# %%
data2.corr()#using the numerically converted values
# Out:
#                   survived    pclass       sex       age     sibsp     parch  \
# survived          1.000000 -0.345752 -0.530699 -0.118939 -0.067761  0.140987
# pclass           -0.345752  1.000000  0.162362 -0.091831  0.088329 -0.033711
# sex              -0.530699  0.162362  1.000000  0.104893 -0.108998 -0.256026
# age              -0.118939 -0.091831  0.104893  1.000000 -0.285324 -0.463143
# sibsp            -0.067761  0.088329 -0.108998 -0.285324  1.000000  0.525630
# parch             0.140987 -0.033711 -0.256026 -0.463143  0.525630  1.000000
# fare              0.222632 -0.560291 -0.173839 -0.014672  0.183781  0.234540
# embarked         -0.162299  0.116644  0.099670 -0.052398  0.086955  0.037359
# who               0.268454 -0.187222 -0.566095  0.550589 -0.160652 -0.184163
# deck              0.121127  0.057732 -0.100945 -0.075604 -0.007020  0.053541
# embark_town      -0.162299  0.116644  0.099670 -0.052398  0.086955  0.037359
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data2.corr(),annot=True)
# Out:
# <Axes: >

# %%
data2.head()
# Out:
#    survived  pclass  sex        age  sibsp  parch     fare  embarked  who  \
# 0         0       3    1  22.000000      1      0   7.2500         2    1
# 2         1       3    0  26.000000      0      0   7.9250         2    2
# 3         1       1    0  35.000000      1      0  53.1000         2    2
# 4         0       3    1  35.000000      0      0   8.0500         2    1
# 5         0       3    1  29.699118      0      0   8.4583         1    1
#
#    deck  embark_town  alive  alone_False  alone_True  adult_male_False  \
# 0     2            2      0            1           0                 0
# 2     2            2      1            0           1                 1
# 3     2            2      1            1           0                 1
# 4     2            2      0            0           1                 0
# 5     2            1      0            0           1                 0
#
#    adult_male_True  class_First  class_Second  class_Third
# ...

# %%
##  y is the dependent variable here other factors influence whether the person is survived or alive or not
y1=data2['survived']
y1.head()
# Out:
# 0    0
# 2    1
# 3    1
# 4    0
# 5    0
# Name: survived, dtype: int64

# %%
y2=data2['alive']
y2.head()
# Out:
# 0    0
# 2    1
# 3    1
# 4    0
# 5    0
# Name: alive, dtype: int32

# %%
# X is independent variable or predictors it removes the dependent variable from the dataset
x=data2.drop(columns=['survived','alive'],axis=1)
x.head()
# Out:
#    pclass  sex        age  sibsp  parch     fare  embarked  who  deck  \
# 0       3    1  22.000000      1      0   7.2500         2    1     2
# 2       3    0  26.000000      0      0   7.9250         2    2     2
# 3       1    0  35.000000      1      0  53.1000         2    2     2
# 4       3    1  35.000000      0      0   8.0500         2    1     2
# 5       3    1  29.699118      0      0   8.4583         1    1     2
#
#    embark_town  alone_False  alone_True  adult_male_False  adult_male_True  \
# 0            2            1           0                 0                1
# 2            2            0           1                 1                0
# 3            2            1           0                 1                0
# 4            2            0           1                 0                1
# 5            1            0           1                 0                1
#
#    class_First  class_Second  class_Third
# 0            0             0            1
# ...

# %% [markdown]
# #### Splitting the data into dependent and independent variables completed

# %% [markdown]
# ## 9. Scale the independent variables

# %%
name=x.columns
name
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'who',
#        'deck', 'embark_town', 'alone_False', 'alone_True', 'adult_male_False',
#        'adult_male_True', 'class_First', 'class_Second', 'class_Third'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(x)
X_scaled
# Out:
# array([[1.        , 1.        , 0.62406015, ..., 0.        , 0.        ,
#         1.        ],
#        [1.        , 0.        , 0.73973395, ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.        , 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.8467067 , ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 1.        , 0.73973395, ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.91324465, ..., 0.        , 0.        ,
#         1.        ]])

# %%
x1=pd.DataFrame(X_scaled,columns=name)
x1
# Out:
#      pclass  sex       age  sibsp  parch      fare  embarked  who      deck  \
# 0       1.0  1.0  0.624060  0.125    0.0  0.014151       1.0  0.5  0.333333
# 1       1.0  0.0  0.739734  0.000    0.0  0.015469       1.0  1.0  0.333333
# 2       0.0  0.0  1.000000  0.125    0.0  0.103644       1.0  1.0  0.333333
# 3       1.0  1.0  1.000000  0.000    0.0  0.015713       1.0  0.5  0.333333
# 4       1.0  1.0  0.846707  0.000    0.0  0.016510       0.5  0.5  0.333333
# ..      ...  ...       ...    ...    ...       ...       ...  ...       ...
# 669     0.5  1.0  0.768652  0.000    0.0  0.025374       1.0  0.5  0.333333
# 670     0.0  0.0  0.537305  0.000    0.0  0.058556       1.0  1.0  0.166667
# 671     1.0  0.0  0.846707  0.125    0.5  0.045771       1.0  1.0  0.333333
# 672     0.0  1.0  0.739734  0.000    0.0  0.058556       0.0  0.5  0.333333
# 673     1.0  1.0  0.913245  0.000    0.0  0.015127       0.5  0.5  0.333333
#
# ...

# %% [markdown]
# #### completed scaling of the independent variables

# %% [markdown]
# ## 10. Split the data into training and testing

# %% [markdown]
# #### since we have more than one dependent variable so we have to split the data twice yet they give same ans because the members who survived are alive
#
# #### for survived

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=0)
X_train.head()
# Out:
#      pclass  sex       age  sibsp  parch      fare  embarked  who      deck  \
# 642     0.5  1.0  0.797571  0.000   0.25  0.064412       1.0  0.5  0.333333
# 101     0.5  1.0  0.927704  0.125   0.00  0.058694       0.0  0.5  0.333333
# 263     0.5  1.0  0.710816  0.000   0.00  0.025374       1.0  0.5  0.333333
# 161     1.0  1.0  0.913245  0.125   0.00  0.030937       1.0  0.5  0.333333
# 327     1.0  1.0  0.595142  0.000   0.00  0.015094       0.5  0.5  0.333333
#
#      embark_town  alone_False  alone_True  adult_male_False  adult_male_True  \
# 642          1.0          1.0         0.0               0.0              1.0
# 101          0.0          1.0         0.0               0.0              1.0
# 263          1.0          0.0         1.0               0.0              1.0
# 161          1.0          1.0         0.0               0.0              1.0
# 327          0.5          0.0         1.0               0.0              1.0
#
#      class_First  class_Second  class_Third
# ...

# %%
X_test.head()
# Out:
#      pclass  sex       age  sibsp  parch      fare  embarked  who      deck  \
# 316     1.0  0.0  0.846707  0.375   0.25  0.049708       1.0  1.0  0.333333
# 31      0.5  0.0  0.768652  0.125   0.00  0.040989       1.0  1.0  0.333333
# 651     1.0  0.0  0.846707  1.000   0.50  0.135753       1.0  1.0  0.333333
# 536     1.0  1.0  0.846707  0.000   0.00  0.030254       0.5  0.5  0.333333
# 113     1.0  1.0  0.450549  0.000   0.00  0.017990       1.0  0.5  0.333333
#
#      embark_town  alone_False  alone_True  adult_male_False  adult_male_True  \
# 316          1.0          1.0         0.0               1.0              0.0
# 31           1.0          1.0         0.0               1.0              0.0
# 651          1.0          1.0         0.0               1.0              0.0
# 536          0.5          0.0         1.0               0.0              1.0
# 113          1.0          0.0         1.0               0.0              1.0
#
#      class_First  class_Second  class_Third
# ...

# %%
y_train
# Out:
# 848    0
# 122    0
# 343    0
# 206    0
# 421    0
#       ..
# 12     0
# 466    0
# 243    0
# 833    0
# 744    1
# Name: survived, Length: 539, dtype: int64

# %%
y_test
# Out:
# 409    0
# 41     0
# 863    0
# 718    0
# 138    0
#       ..
# 575    0
# 91     0
# 204    1
# 830    1
# 888    0
# Name: survived, Length: 135, dtype: int64

# %% [markdown]
# #### for alive

# %%
X_train,X_test,y_train,y_test=train_test_split(x1,y2,test_size=0.2,random_state=0)
X_train.head()
# Out:
#      pclass  sex       age  sibsp  parch      fare  embarked  who      deck  \
# 642     0.5  1.0  0.797571  0.000   0.25  0.064412       1.0  0.5  0.333333
# 101     0.5  1.0  0.927704  0.125   0.00  0.058694       0.0  0.5  0.333333
# 263     0.5  1.0  0.710816  0.000   0.00  0.025374       1.0  0.5  0.333333
# 161     1.0  1.0  0.913245  0.125   0.00  0.030937       1.0  0.5  0.333333
# 327     1.0  1.0  0.595142  0.000   0.00  0.015094       0.5  0.5  0.333333
#
#      embark_town  alone_False  alone_True  adult_male_False  adult_male_True  \
# 642          1.0          1.0         0.0               0.0              1.0
# 101          0.0          1.0         0.0               0.0              1.0
# 263          1.0          0.0         1.0               0.0              1.0
# 161          1.0          1.0         0.0               0.0              1.0
# 327          0.5          0.0         1.0               0.0              1.0
#
#      class_First  class_Second  class_Third
# ...

# %%
X_test.head()
# Out:
#      pclass  sex       age  sibsp  parch      fare  embarked  who      deck  \
# 316     1.0  0.0  0.846707  0.375   0.25  0.049708       1.0  1.0  0.333333
# 31      0.5  0.0  0.768652  0.125   0.00  0.040989       1.0  1.0  0.333333
# 651     1.0  0.0  0.846707  1.000   0.50  0.135753       1.0  1.0  0.333333
# 536     1.0  1.0  0.846707  0.000   0.00  0.030254       0.5  0.5  0.333333
# 113     1.0  1.0  0.450549  0.000   0.00  0.017990       1.0  0.5  0.333333
#
#      embark_town  alone_False  alone_True  adult_male_False  adult_male_True  \
# 316          1.0          1.0         0.0               1.0              0.0
# 31           1.0          1.0         0.0               1.0              0.0
# 651          1.0          1.0         0.0               1.0              0.0
# 536          0.5          0.0         1.0               0.0              1.0
# 113          1.0          0.0         1.0               0.0              1.0
#
#      class_First  class_Second  class_Third
# ...

# %%
y_train
# Out:
# 848    0
# 122    0
# 343    0
# 206    0
# 421    0
#       ..
# 12     0
# 466    0
# 243    0
# 833    0
# 744    1
# Name: alive, Length: 539, dtype: int32

# %%
y_test
# Out:
# 409    0
# 41     0
# 863    0
# 718    0
# 138    0
#       ..
# 575    0
# 91     0
# 204    1
# 830    1
# 888    0
# Name: alive, Length: 135, dtype: int32

# %% [markdown]
# ##  Completed Splitting of the data into training and testing
